0.07115607364334148, -0.17823131139349618, -0.15988924479972694, -0.048512493804446236, 0.19495221406340427, -0.00036815081749359043, 0.07927013598334857, -0.19465376868872888, -0.09454684483923122, -0.05436105053327428, 0.01785669168492629, -0.07783354479625104, 0.04496299052226327, -0.009288924403020996, 0.07632207875133427, -0.011578729287268188, -0.18099659343923807, 0.03424285702641155, -0.39214684950594536, -0.007532944878684435, 0.0062153844770555695, 0.001707466387562031, -0.05172108011366077, 0.1554159946223401, 0.08534842061413495, -0.03558722002198483, 0.05083476458268161, 0.06462405565036794, -0.17804878202576985, -0.022873913118726864, 0.21647354677064956, -0.09974293309696484, 0.08135441911426093, -0.1091812511991538, 0.013829685831785721, -0.09129213818348175, -0.11570135688450249, -0.0179011362938564, -0.02174016529116442, -0.012090327024494672, 0.18597306081657344, -0.13193301205338237, 0.05685681274366199, 0.23204757949735616, -0.008605723879311307, -0.05304394812101925, -0.005749791406011717, -0.030650275432360933, 0.14706233275020597, -0.15162003634718244, -0.3813911 ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(x,y)
ax.axis([min(x), max(x), min(y), max(y)])
# Out:
# (-0.4628031167105273,
#  0.289859164481942,
#  -412.08027695872767,
#  -411.2836112651495)

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# %%
from mpl_toolkits.mplot3d import Axes3D

ax = Axes3D(fig)
# Out:
# C:\Users\seung\AppData\Local\Temp/ipykernel_22684/2512745963.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
fig = plt.figure(figsize=(10, 3))
ax0 = fig.add_subplot(131, projection="3d")
ax1 = fig.add_subplot(132, projection="3d")
ax2 = fig.add_subplot(133, projection="3d")

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10,6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(x,y,z,rstride=2,cstride=2,cmap=plt.cm.coolwarm,linewidth=0.5,antialiased=True)
ax.view_init(0,60)
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
plt.title('3D')
fig.colorbar(surf,shrink=0.5,aspect=5)
fig.plot(x,y,z)
# Out:
# C:\Users\seung\AppData\Local\Temp/ipykernel_22684/2457895337.py:4: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22684/2457895337.py in <module>
#       3 fig = plt.figure(figsize=(10,6))
#       4 ax = fig.gca(projection='3d')
# ----> 5 surf = ax.plot_surface(x,y,z,rstride=2,cstride=2,cmap=plt.cm.coolwarm,linewidth=0.5,antialiased=True)
#       6 ax.view_init(0,60)
#       7 ax.set_xlabel('x axis')
#
# c:\users\seung\appdata\local\programs\python\python39\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# c:\users\seung\appdata\local\programs\python\python39\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1578         had_data = self.has_data()
#    1579
# -> 1580         if Z.ndim != 2:
#    1581             raise ValueError("Argument Z must be 2-dimensional.")
#    1582
#
# AttributeError: 'list' object has no attribute 'ndim'
